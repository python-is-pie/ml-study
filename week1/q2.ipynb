# %%
import pandas as pd

def answer_two():
    path = './world_bank2020.csv'
    GDP_df = pd.read_csv(path, skiprows=4)
    GDP_df = GDP_df.filter(regex='(Country Name|20(1[1-9]|20))', axis=1)
    GDP_df = GDP_df.rename(columns={"Country Name": "Country"})
    GDP_df = GDP_df.set_index("Country")
    GDP_df = GDP_df.rename(index= {"Korea, Rep.":"South Korea","Iran, Islamic Rep.":"Iran", 
                                   "Hong Kong SAR, China": "Hong Kong"})
    return GDP_df

answer_two()
# Out:
#                                      2011          2012          2013  \
# Country
# Aruba                        2.549721e+09  2.534637e+09  2.727850e+09
# Africa Eastern and Southern  9.433782e+11  9.505214e+11  9.642424e+11
# Afghanistan                  1.780511e+10  1.990732e+10  2.014640e+10
# Africa Western and Central   6.709626e+11  7.275714e+11  8.207876e+11
# Angola                       1.117897e+11  1.280529e+11  1.367099e+11
# ...                                   ...           ...           ...
# Kosovo                       6.341737e+09  6.163785e+09  6.735731e+09
# Yemen, Rep.                  3.272642e+10  3.540134e+10  4.041524e+10
# South Africa                 4.582015e+11  4.344005e+11  4.008860e+11
# Zambia                       2.345952e+10  2.550306e+10  2.803724e+10
# Zimbabwe                     1.410192e+10  1.711485e+10  1.909102e+10
#
#                                      2014          2015          2016  \
# Country
# Aruba                        2.790849e+09  2.962905e+09  2.983637e+09
# Africa Eastern and Southern  9.848071e+11  9.199300e+11  8.733549e+11
# Afghanistan                  2.049713e+10  1.913421e+10  1.811656e+10
# Africa Western and Central   8.649666e+11  7.607297e+11  6.905430e+11
# Angola                       1.457122e+11  1.161936e+11  1.011239e+11
# ...                                   ...           ...           ...
# Kosovo                       7.074658e+09  6.295820e+09  6.682833e+09
# Yemen, Rep.                  4.322859e+10  4.244510e+10  3.131737e+10
# South Africa                 3.811989e+11  3.467098e+11  3.235855e+11
# Zambia                       2.714102e+10  2.125122e+10  2.095841e+10
# Zimbabwe                     1.949552e+10  1.996312e+10  2.054868e+10
#
#                                      2017          2018          2019  \
# Country
# Aruba                        3.092430e+09  3.202189e+09           NaN
# Africa Eastern and Southern  9.853557e+11  1.012853e+12  1.009910e+12
# Afghanistan                  1.875347e+10  1.805323e+10  1.879945e+10
# Africa Western and Central   6.837416e+11  7.416916e+11  7.945725e+11
# Angola                       1.221238e+11  1.013532e+11  8.941719e+10
# ...                                   ...           ...           ...
# Kosovo                       7.180813e+09  7.878509e+09  7.899879e+09
# Yemen, Rep.                  2.684013e+10  2.160614e+10           NaN
# South Africa                 3.814488e+11  4.048421e+11  3.879346e+11
# Zambia                       2.587360e+10  2.631159e+10  2.330867e+10
# Zimbabwe                     1.758489e+10  1.811554e+10  1.928429e+10
#
#                                      2020
# Country
# Aruba                                 NaN
# Africa Eastern and Southern  9.207923e+11
# Afghanistan                  2.011614e+10
# Africa Western and Central   7.845876e+11
# Angola                       5.837598e+10
# ...                                   ...
# Kosovo                       7.716925e+09
# Yemen, Rep.                           NaN
# South Africa                 3.354421e+11
# Zambia                       1.811063e+10
# Zimbabwe                     1.805117e+10
#
# [266 rows x 10 columns]

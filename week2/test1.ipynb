# %%
from popdataload import *
from getnuminfo import *
from vizpopulationinfo import *

# %%
df = load_data()
df
# Out:
#             행정구역별       총인구        남자        여자     내국인-계    내국인-남자    내국인-여자  \
# 0              전국  51829136  25915207  25913929  50133493  24972588  25160905
# 1              읍부   5113052   2624351   2488701   4904647   2494271   2410376
# 2              면부   4650781   2420392   2230389   4394145   2237761   2156384
# 3              동부  42065303  20870464  21194839  40834701  20240556  20594145
# 4           서울특별시   9586195   4647733   4938462   9219741   4474343   4745398
# ..            ...       ...       ...       ...       ...       ...       ...
# 319    제주특별자치도 읍부    153767     79230     74537    143607     72697     70910
# 320    제주특별자치도 면부     35539     18365     17174     33603     17103     16500
# 321    제주특별자치도 동부    481552    240578    240974    466817    233204    233613
# 322   제주특별자치도 제주시    492306    247474    244832    474196    237502    236694
# 323  제주특별자치도 서귀포시    178552     90699     87853    169831     85502     84329
#
# ...

# %%
get_rank(df,'부산광역시 남구', '일반가구')
# Out:
# 5.0

# %%
get_num_of_districts(df, area = '부산광역시')
# Out:
# 16

# %%
top5graph(df, feature='외국인-계')
# Out:
#       행정구역별       총인구        남자        여자     내국인-계    내국인-남자    내국인-여자  \
# 0        전국  51829136  25915207  25913929  50133493  24972588  25160905
# 3        동부  42065303  20870464  21194839  40834701  20240556  20594145
# 102     경기도  13511676   6828367   6683309  12928214   6489718   6438496
# 105  경기도 동부  11212096   5605921   5606175  10801613   5389990   5411623
# 4     서울특별시   9586195   4647733   4938462   9219741   4474343   4745398
#
#        외국인-계  외국인-남자  외국인-여자  ...      일반가구   집단가구   외국인가구      주택-계     단독주택  \
# 0    1695643  942619  753024  ...  20926710  16388  541687  18525844  3897729
# 3    1230602  629908  600694  ...  16896701   9798  429024  14427931  1778105
# 102   583462  338649  244813  ...   5098431   4080  192325   4495115   505382
# 105   410483  215931  194552  ...   4235667   2341  149111   3677426   257141
# 4     366454  173390  193064  ...   3982290   2264  141970   3015371   307075
#
#           아파트    연립주택    다세대주택  비거주용 건물내 주택  주택이외의 거처
# ...

# %%
circlegraph(df, feature='외국인가구')
# Out:
# <AxesSubplot:title={'center':'상위 5개의 지역'}, ylabel='외국인가구'>
